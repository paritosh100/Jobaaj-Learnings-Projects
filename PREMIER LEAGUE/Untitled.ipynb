# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('epl_results_2022-23.csv')

# %%
df.head()
# Out:
#          Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  05/08/2022  20:00  Crystal Palace      Arsenal     0     2   A     0     1
# 1  06/08/2022  12:30          Fulham    Liverpool     2     2   D     1     0
# 2  06/08/2022  15:00     Bournemouth  Aston Villa     2     0   H     1     0
# 3  06/08/2022  15:00           Leeds       Wolves     2     1   H     1     1
# 4  06/08/2022  15:00       Newcastle   Nottingham     2     0   H     0     0
#
#   HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0   A  ...   2    2  16  11   3   5   1   2   0   0
# 1   H  ...   3    4   7   9   4   4   2   0   0   0
# 2   H  ...   3    2  18  16   5   5   3   3   0   0
# 3   D  ...   4    6  13   9   6   4   2   0   0   0
# 4   D  ...  10    0   9  14  11   1   0   3   0   0
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (380, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      380 non-null    object
#  1   Time      380 non-null    object
#  2   HomeTeam  380 non-null    object
#  3   AwayTeam  380 non-null    object
#  4   FTHG      380 non-null    int64
#  5   FTAG      380 non-null    int64
#  6   FTR       380 non-null    object
#  7   HTHG      380 non-null    int64
#  8   HTAG      380 non-null    int64
#  9   HTR       380 non-null    object
#  10  Referee   380 non-null    object
#  11  HS        380 non-null    int64
#  12  AS        380 non-null    int64
#  13  HST       380 non-null    int64
#  14  AST       380 non-null    int64
#  15  HF        380 non-null    int64
#  16  AF        380 non-null    int64
#  17  HC        380 non-null    int64
#  18  AC        380 non-null    int64
#  19  HY        380 non-null    int64
# ...

# %%
copy_df= df.copy()

# %%
copy_df.head()
# Out:
#          Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  05/08/2022  20:00  Crystal Palace      Arsenal     0     2   A     0     1
# 1  06/08/2022  12:30          Fulham    Liverpool     2     2   D     1     0
# 2  06/08/2022  15:00     Bournemouth  Aston Villa     2     0   H     1     0
# 3  06/08/2022  15:00           Leeds       Wolves     2     1   H     1     1
# 4  06/08/2022  15:00       Newcastle   Nottingham     2     0   H     0     0
#
#   HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0   A  ...   2    2  16  11   3   5   1   2   0   0
# 1   H  ...   3    4   7   9   4   4   2   0   0   0
# 2   H  ...   3    2  18  16   5   5   3   3   0   0
# 3   D  ...   4    6  13   9   6   4   2   0   0   0
# 4   D  ...  10    0   9  14  11   1   0   3   0   0
#
# [5 rows x 23 columns]

# %%
copy_df['HomeTeam'].value_counts()
# Out:
# Nottingham        19
# Leeds             19
# Chelsea           19
# Aston Villa       19
# West Ham          19
# Brighton          19
# Liverpool         19
# Everton           19
# Bournemouth       19
# Southampton       19
# Wolves            19
# Man United        19
# Tottenham         19
# Leicester         19
# Fulham            19
# Crystal Palace    19
# Newcastle         19
# Brentford         19
# Arsenal           19
# Man City          19
# Name: HomeTeam, dtype: int64

# %%
man_utd_home = copy_df[copy_df['HomeTeam'] == "Man United"  ]

# %%
man_utd_home
# Out:
#            Date   Time    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 8    07/08/2022  14:00  Man United        Brighton     1     2   A     0
# 29   22/08/2022  20:00  Man United       Liverpool     2     1   H     1
# 59   04/09/2022  16:30  Man United         Arsenal     3     1   H     1
# 94   16/10/2022  14:00  Man United       Newcastle     0     0   D     0
# 103  19/10/2022  20:15  Man United       Tottenham     2     0   H     0
# 125  30/10/2022  16:15  Man United        West Ham     1     0   H     1
# 154  27/12/2022  20:00  Man United      Nottingham     3     0   H     2
# 170  03/01/2023  20:00  Man United     Bournemouth     3     0   H     1
# 178  14/01/2023  12:30  Man United        Man City     2     1   H     0
# 204  04/02/2023  15:00  Man United  Crystal Palace     2     1   H     1
# 209  08/02/2023  20:00  Man United           Leeds     2     2   D     0
# 229  19/02/2023  14:00  Man United       Leicester     3     0   H     1
# ...

# %%
    man_utd_home.columns
# Out:
# Index(['Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC',
#        'AC', 'HY', 'AY', 'HR', 'AR'],
#       dtype='object')

# %%
man_utd_home.FTHG.sum()
# Out:
# 36

# %%
man_utd_home.FTAG.sum()
# Out:
# 10

# %%
plt.figure(figsize = (20,10))
sns.histplot(data = man_utd_home,x = 'FTHG' )

# %%
plt.figure(figsize = (20,10))
sns.histplot(data = man_utd_home,x = 'FTAG' )

# %%
man_utd_away = copy_df[copy_df['AwayTeam'] == "Man United"]

# %%
man_utd_away
# Out:
#            Date   Time        HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  \
# 16   13/08/2022  17:30       Brentford  Man United     4     0   H     4
# 30   27/08/2022  12:30     Southampton  Man United     0     1   A     0
# 49   01/09/2022  20:00       Leicester  Man United     0     1   A     0
# 74   02/10/2022  14:00        Man City  Man United     6     3   H     4
# 85   09/10/2022  19:00         Everton  Man United     1     2   A     1
# 109  22/10/2022  17:30         Chelsea  Man United     1     1   D     0
# 132  06/11/2022  14:00     Aston Villa  Man United     3     1   H     2
# 145  13/11/2022  16:30          Fulham  Man United     1     2   A     0
# 158  31/12/2022  12:30          Wolves  Man United     0     1   A     0
# 187  18/01/2023  20:00  Crystal Palace  Man United     1     1   D     0
# 197  22/01/2023  16:30         Arsenal  Man United     3     2   H     1
# 217  12/02/2023  14:00           Leeds  Man United     0     2   A     0
# ...

# %%
man_utd_away.FTHG.sum() + man_utd_home.FTAG.sum()
# Out:
# 43

# %%
man_utd_away.FTAG.sum() + man_utd_home.FTHG.sum()
# Out:
# 58

# %%
away_conceded = man_utd_away['FTHG'].max()
away_conceded
# Out:
# 7

# %%
away_scored = man_utd_away['FTAG'].max()
away_scored
# Out:
# 3

# %%
home_scored = man_utd_home['FTHG'].max()
home_scored
# Out:
# 4

# %%
home_conceded = man_utd_home['FTAG'].max()
home_conceded
# Out:
# 2

# %%
values = [home_scored,home_conceded,away_scored,away_conceded]
data = ['home_scored','home_conceded','away_scored','away_conceded']

# %%
plt.figure(figsize = (10,5))
sns.barplot(x = data,y=values,width=0.5 )

# %%
manc_home = copy_df[copy_df["HomeTeam"]=="Man City"]

# %%
manc_home
# Out:
#            Date   Time  HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 13   13/08/2022  15:00  Man City     Bournemouth     4     0   H     3     0
# 35   27/08/2022  15:00  Man City  Crystal Palace     4     2   H     0     2
# 46   31/08/2022  19:30  Man City      Nottingham     6     0   H     3     0
# 74   02/10/2022  14:00  Man City      Man United     6     3   H     4     0
# 79   08/10/2022  15:00  Man City     Southampton     4     0   H     2     0
# 108  22/10/2022  15:00  Man City        Brighton     3     1   H     2     0
# 127  05/11/2022  15:00  Man City          Fulham     2     1   H     1     1
# 136  12/11/2022  12:30  Man City       Brentford     1     2   A     1     1
# 161  31/12/2022  15:00  Man City         Everton     1     1   D     1     0
# 188  19/01/2023  20:00  Man City       Tottenham     4     2   H     0     2
# 196  22/01/2023  14:00  Man City          Wolves     3     0   H     1     0
# ...

# %%
frames =[man_utd_home, man_utd_away]

# %%
man_utd_overall =pd.concat(frames)

# %%
pd.DataFrame(man_utd_overall)
# Out:
#            Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 8    07/08/2022  14:00      Man United        Brighton     1     2   A     0
# 29   22/08/2022  20:00      Man United       Liverpool     2     1   H     1
# 59   04/09/2022  16:30      Man United         Arsenal     3     1   H     1
# 94   16/10/2022  14:00      Man United       Newcastle     0     0   D     0
# 103  19/10/2022  20:15      Man United       Tottenham     2     0   H     0
# 125  30/10/2022  16:15      Man United        West Ham     1     0   H     1
# 154  27/12/2022  20:00      Man United      Nottingham     3     0   H     2
# 170  03/01/2023  20:00      Man United     Bournemouth     3     0   H     1
# 178  14/01/2023  12:30      Man United        Man City     2     1   H     0
# 204  04/02/2023  15:00      Man United  Crystal Palace     2     1   H     1
# 209  08/02/2023  20:00      Man United           Leeds     2     2   D     0
# ...

# %%
man_utd_overall["FTHG"][:19].sum()
# Out:
# 36

# %%
man_utd_overall["FTAG"][20:].sum()
# Out:
# 22

# %%
man_utd_scored = man_utd_overall["FTHG"][:19].sum()+man_utd_overall["FTAG"][20:].sum()

# %%
man_utd_scored
# Out:
# 58

# %%
man_utd_conceded = man_utd_overall["FTAG"][:19].sum()+man_utd_overall["FTHG"][20:].sum()

# %%
man_utd_conceded
# Out:
# 39

# %%
pd.DataFrame([man_utd_scored,man_utd_conceded])
# Out:
#     0
# 0  58
# 1  39

# %%
value_sc = [man_utd_scored,man_utd_conceded]
data_sc = ['man_utd_scored','man_utd_conceded']

# %%
plt.figure(figsize = (10,5))
plt.title("MANCHESTER UNITED TOTAL SCORED AND CONCEDED GOALS",fontdict={'size':16,'weight':'bold'})
sns.barplot(x = data_sc,y=value_sc,width=0.5 )

# %%
manc_away = copy_df[copy_df["AwayTeam"]=="Man City"]

# %%
manc_away
# Out:
#            Date   Time        HomeTeam  AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 9    07/08/2022  16:30        West Ham  Man City     0     2   A     0     1
# 28   21/08/2022  16:30       Newcastle  Man City     3     3   D     2     1
# 57   03/09/2022  17:30     Aston Villa  Man City     1     1   D     0     0
# 62   17/09/2022  12:30          Wolves  Man City     0     3   A     0     2
# 96   16/10/2022  16:30       Liverpool  Man City     1     0   H     0     0
# 116  29/10/2022  12:30       Leicester  Man City     0     1   A     0     0
# 155  28/12/2022  20:00           Leeds  Man City     1     3   A     0     1
# 175  05/01/2023  20:00         Chelsea  Man City     0     1   A     0     0
# 178  14/01/2023  12:30      Man United  Man City     2     1   H     0     0
# 208  05/02/2023  16:30       Tottenham  Man City     1     0   H     1     0
# 220  15/02/2023  19:30         Arsenal  Man City     1     3   A     1     1
# ...

# %%
frames1 = [manc_home,manc_away]

# %%
manc_overall = pd.concat(frames1)

# %%
manc_overall
# Out:
#            Date   Time        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 13   13/08/2022  15:00        Man City     Bournemouth     4     0   H     3
# 35   27/08/2022  15:00        Man City  Crystal Palace     4     2   H     0
# 46   31/08/2022  19:30        Man City      Nottingham     6     0   H     3
# 74   02/10/2022  14:00        Man City      Man United     6     3   H     4
# 79   08/10/2022  15:00        Man City     Southampton     4     0   H     2
# 108  22/10/2022  15:00        Man City        Brighton     3     1   H     2
# 127  05/11/2022  15:00        Man City          Fulham     2     1   H     1
# 136  12/11/2022  12:30        Man City       Brentford     1     2   A     1
# 161  31/12/2022  15:00        Man City         Everton     1     1   D     1
# 188  19/01/2023  20:00        Man City       Tottenham     4     2   H     0
# 196  22/01/2023  14:00        Man City          Wolves     3     0   H     1
# ...

# %%
manc_scored =manc_overall['FTHG'][:20].sum()+ manc_overall['FTAG'][20:].sum()

# %%
manc_conceded = manc_overall['FTAG'][:20].sum()+ manc_overall['FTHG'][20:].sum()

# %%
value_sc_mc = [manc_scored,man_utd_scored,man_utd_conceded,manc_conceded]
data_sc_mc = ['MANCHESTER CITY SCORED','MANCHESTER UNITED SCORED','MANCHESTER CITY CONCEDED','MANCHESTER UNITED CONCEDED']

# %%
plt.figure(figsize = (15,5))
plt.title("MANCHESTER CITY & UNITED TOTAL SCORED AND CONCEDED GOALS",fontdict={'size':16,'weight':'bold'})
sns.barplot(x = data_sc_mc,y=value_sc_mc,width=0.2, )

# %%
x = ['MANCHESTER UNITED ','MANCHESTER CITY ']
scored = [man_utd_scored,manc_scored]
conceded = [man_utd_conceded,manc_conceded]

# %%
plt.figure(figsize=(10,7))
plt.bar(x,scored,0.4,label = "SCORED")
plt.bar(x,conceded,0.4,label = "CONCEDED",bottom = scored)

plt.xlabel("TEAMS",fontdict={'weight':'bold','Size':16})
plt.ylabel("TOTAL GOALS",fontdict={'weight':'bold','Size':16})
plt.title("MANCHESTER UNITED VS MANCHESTER CITY",fontdict={'weight':'bold','Size':20})
plt.legend()
plt.show()

# %%
man_utd_overall[['Time','HomeTeam','AwayTeam','FTHG','FTAG','FTR']]
# Out:
#       Time        HomeTeam        AwayTeam  FTHG  FTAG FTR
# 8    14:00      Man United        Brighton     1     2   A
# 29   20:00      Man United       Liverpool     2     1   H
# 59   16:30      Man United         Arsenal     3     1   H
# 94   14:00      Man United       Newcastle     0     0   D
# 103  20:15      Man United       Tottenham     2     0   H
# 125  16:15      Man United        West Ham     1     0   H
# 154  20:00      Man United      Nottingham     3     0   H
# 170  20:00      Man United     Bournemouth     3     0   H
# 178  12:30      Man United        Man City     2     1   H
# 204  15:00      Man United  Crystal Palace     2     1   H
# 209  20:00      Man United           Leeds     2     2   D
# 229  14:00      Man United       Leicester     3     0   H
# 258  14:00      Man United     Southampton     0     0   D
# 284  20:00      Man United       Brentford     1     0   H
# 286  12:30      Man United         Everton     2     0   H
# ...

# %%
man_utd_overall['Time'].dtypes
# Out:
# dtype('O')

# %%
man_utd_home[man_utd_home['Time'] == '20:00' ]
# Out:
#            Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 29   22/08/2022  20:00  Man United    Liverpool     2     1   H     1     0
# 154  27/12/2022  20:00  Man United   Nottingham     3     0   H     2     0
# 170  03/01/2023  20:00  Man United  Bournemouth     3     0   H     1     0
# 209  08/02/2023  20:00  Man United        Leeds     2     2   D     0     1
# 284  05/04/2023  20:00  Man United    Brentford     1     0   H     1     0
# 369  25/05/2023  20:00  Man United      Chelsea     4     1   H     2     0
#
#     HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 29    H  ...   4    5  11   7   6   8   3   1   0   0
# 154   H  ...   8    3  13   4   9   9   3   1   0   0
# 170   H  ...   6    4  13   7   6   5   0   3   0   0
# 209   A  ...   7    2   7  11   6   5   1   3   0   0
# 284   H  ...   3    1   8  13  12   3   3   2   0   0
# 369   H  ...   9    5  12   6   3   4   1   1   0   0
#
# [6 rows x 23 columns]

# %%
man_utd_away[man_utd_away['Time'] == '20:00' ]
# Out:
#            Date   Time        HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  \
# 49   01/09/2022  20:00       Leicester  Man United     0     1   A     0
# 187  18/01/2023  20:00  Crystal Palace  Man United     1     1   D     0
# 336  04/05/2023  20:00        Brighton  Man United     1     0   H     0
#
#      HTAG HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 49      1   A  ...   2    2   7  15   1   3   1   3   0   0
# 187     1   A  ...   5    4   9  10   3   3   1   2   0   0
# 336     0   D  ...   6    5  10  14   8   6   4   4   0   0
#
# [3 rows x 23 columns]

# %% [markdown]
# ## From the above output, we can say that games played at 20:00hrs have higher chances of wining at home and as well as at away situations.

# %% [markdown]
# ## Man Utd have won 5 out of 6 home games held at 20:00hrs and tied 1 with 0 lost.

# %% [markdown]
# ## Man Utd have won 1 out of 3 away matches with 1 draw and 1 loss @20:00hrs, so the away record is balanced not leaning towards any situation. <br>
# ## The total is 6 wins, 2 draws, and 1 loss in games held @20:00hrs

# %% [markdown]
# <hr>

# %% [markdown]
# # Calculating win rate @14:00

# %%
man_utd_overall['Time'].value_counts()
# Out:
# 20:00    9
# 14:00    8
# 16:30    7
# 12:30    4
# 15:00    3
# 19:00    2
# 17:30    2
# 20:15    2
# 16:15    1
# Name: Time, dtype: int64

# %%
man_utd_overall[man_utd_overall['Time'] == '14:00' ]
# Out:
#            Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 8    07/08/2022  14:00   Man United     Brighton     1     2   A     0     2
# 94   16/10/2022  14:00   Man United    Newcastle     0     0   D     0     0
# 229  19/02/2023  14:00   Man United    Leicester     3     0   H     1     0
# 258  12/03/2023  14:00   Man United  Southampton     0     0   D     0     0
# 329  30/04/2023  14:00   Man United  Aston Villa     1     0   H     1     0
# 74   02/10/2022  14:00     Man City   Man United     6     3   H     4     0
# 132  06/11/2022  14:00  Aston Villa   Man United     3     1   H     2     1
# 217  12/02/2023  14:00        Leeds   Man United     0     2   A     0     0
#
#     HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 8     A  ...   5    4   7  12   6   2   4   1   0   0
# 94    D  ...   2    2  13  11   4   4   3   1   0   0
# 229   H  ...   8    3   9   9   6   6   0   2   0   0
# 258   D  ...   4    4  12   9   7   8   2   0   0   0
# ...

# %% [markdown]
# ## Man Utd have won 2 out of 5 games at home held @ 14:00 hrs of time, and drew 2 and lost 1.So they have a positive win rate played @14:00hrs at home

# %% [markdown]
# ## In away situations, Man utd have 2 losses and 1 win out of 3 games held @14:00hrs, so it is negatively skewed for Man utd <br>
# ## The total is 3 wins,3 losses, and 2 draws out of 8 games held @14:00hrs

# %% [markdown]
# <hr>

# %% [markdown]
# # Calculating win rate @16:30 time

# %%
man_utd_overall[man_utd_overall['Time'] == '16:30' ]
# Out:
#            Date   Time    HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 59   04/09/2022  16:30  Man United     Arsenal     3     1   H     1     0
# 378  28/05/2023  16:30  Man United      Fulham     2     1   H     1     1
# 145  13/11/2022  16:30      Fulham  Man United     1     2   A     0     1
# 197  22/01/2023  16:30     Arsenal  Man United     3     2   H     1     1
# 249  05/03/2023  16:30   Liverpool  Man United     7     0   H     1     0
# 278  02/04/2023  16:30   Newcastle  Man United     2     0   H     0     0
# 304  16/04/2023  16:30  Nottingham  Man United     0     2   A     0     1
#
#     HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 59    H  ...   6    3  13   9   2   5   3   3   0   0
# 378   D  ...   8    3  14  10   5   4   1   2   0   0
# 145   A  ...   7    9   9  10  10   3   1   1   0   0
# 197   D  ...   5    4   8   9  12   4   1   2   0   0
# 249   H  ...   8    4  13  14   4   3   2   3   0   0
# ...

# %% [markdown]
# ## So there are in total 7 games played @ 16:30. From these 7 games, Man Utd have 2 home games and 5 away games

# %% [markdown]
# ## From these 2 home games Utd have won both the game with 100% win rate, from 5 away games Utd have won only 2 and lost 3 with win rate of 40% and 60% of loss rate

# %% [markdown]
# ## so we can say that at home Utd are flawless but in away conditions Utd seems to mess it up, they need to figure things out to reverse the numbers.

# %% [markdown]
# <hr>

# %% [markdown]
# # Calculating wins for games @ 12:30

# %%
man_utd_overall[man_utd_overall['Time'] == '12:30' ]
# Out:
#            Date   Time     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 178  14/01/2023  12:30   Man United    Man City     2     1   H     0     0
# 286  08/04/2023  12:30   Man United     Everton     2     0   H     1     0
# 30   27/08/2022  12:30  Southampton  Man United     0     1   A     0     0
# 158  31/12/2022  12:30       Wolves  Man United     0     1   A     0     0
#
#     HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 178   D  ...   4    1  15   5   1   2   3   0   0   0
# 286   H  ...  11    1  10   9  10   4   0   0   0   0
# 30    D  ...   5    6   4  14   5   3   0   3   0   0
# 158   D  ...   3    6  11  11   7   5   1   3   0   0
#
# [4 rows x 23 columns]

# %% [markdown]
# ## There are total 4 games played at 12:30 hrs. 2 of them are at home and other at away conditions.

# %% [markdown]
# ## Man Utd look untouchable at 12:30 with 100% combined win rate. They have dropped 0 games at 12:30 hrs

# %% [markdown]
# <hr>

# %% [markdown]
# # Calculating wins for games at 15:00

# %%
man_utd_overall[man_utd_overall['Time'] == '15:00' ]
# Out:
#            Date   Time     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
# 204  04/02/2023  15:00   Man United  Crystal Palace     2     1   H     1
# 351  13/05/2023  15:00   Man United          Wolves     2     0   H     1
# 359  20/05/2023  15:00  Bournemouth      Man United     0     1   A     0
#
#      HTAG HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 204     0   H  ...   5    3   9   9   5   5   1   2   1   0
# 351     0   H  ...   9    0   9   9  11   7   3   2   0   0
# 359     1   A  ...   4    5   6   7   3   6   1   0   0   0
#
# [3 rows x 23 columns]

# %% [markdown]
# ## here as well Utd has 100% of win rate in games played @15:00 hrs

# %% [markdown]
# <hr>

# %% [markdown]
# # Calculating win rate for games @ 19:00,17:30,20:15

# %%
man_utd_overall[man_utd_overall['Time'] == '19:00' ]
# Out:
#            Date   Time  HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 85   09/10/2022  19:00   Everton  Man United     1     2   A     1     2   A
# 343  07/05/2023  19:00  West Ham  Man United     1     0   H     1     0   H
#
#      ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 85   ...   2    4   7  13   5   4   2   1   0   0
# 343  ...   4    4   4   9   5   6   0   2   0   0
#
# [2 rows x 23 columns]

# %%
man_utd_overall[man_utd_overall['Time'] == '17:30' ]
# Out:
#            Date   Time   HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 16   13/08/2022  17:30  Brentford  Man United     4     0   H     4     0   H
# 109  22/10/2022  17:30    Chelsea  Man United     1     1   D     0     0   D
#
#      ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 16   ...   7    4   6  15   8   2   0   4   0   0
# 109  ...   2    6   8  10   6   4   1   4   0   0
#
# [2 rows x 23 columns]

# %%
man_utd_overall[man_utd_overall['Time'] == '20:15' ]
# Out:
#            Date   Time    HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 103  19/10/2022  20:15  Man United   Tottenham     2     0   H     0     0
# 323  27/04/2023  20:15   Tottenham  Man United     2     2   D     0     2
#
#     HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 103   D  ...  10    2   7   7   8   3   1   0   0   0
# 323   A  ...   7    8   8   7   6   8   1   2   0   0
#
# [2 rows x 23 columns]

# %% [markdown]
# ## Utd has 50% win rate for games played at 19:00 on away conditions

# %% [markdown]
# ## Utd has won 0 out of 2 games played at 17:30 hrs, so they need to take actions to convert these numbers into a win. 1 loss and 1 DRAW here

# %% [markdown]
# ## They have 100% win rate at home conditions for games played at 20:15, they have not dropped any of their games but they do have a draw here

# %% [markdown]
# <hr>

# %% [markdown]
# # Calculating win rate @16:15

# %%
man_utd_overall[man_utd_overall['Time'] == '16:15' ]
# Out:
#            Date   Time    HomeTeam  AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 125  30/10/2022  16:15  Man United  West Ham     1     0   H     1     0   H
#
#      ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 125  ...   3    5  12  10   5  10   1   3   0   0
#
# [1 rows x 23 columns]

# %% [markdown]
# # here utd has 100% win rate as only one game was played at this time.

# %% [markdown]
# <hr>
# <hr>

# %% [markdown]
# # Conclusion

# %% [markdown]
# ## MANCHESTER UNITED HAS 100% WIN RATE FOR GAMES PLAYED AT 16:15, @HOME 20:15,15:00,12:30,@HOME 16:30
# ## AND 0 LOSS WITH 5 WINS @20:00 @HOME WITH 1 WIN 1 DRAW AND 1 LOSS HERE
# ## NEED TO TAKE ACTIONS TO IMPROVE @ : 17:30, 19:00
# ## 20:15 = 1 WIN AND 1 DRAW /2
# ## 20:00 = 5 HOME WINS-1 AWAY WIN,1 HOME DRAW- 1 AWAY DRAW,1 AWAY LOSS/9
# ## 19:00 = 1 WIN 1 LOSS /2
# ## 17:30 =  1 LOSS 1 DRAW /2
# ## 16:15 = 1 HOME WIN /1
# ## 15:00 = 2 HOME WINS AND 1 AWAY WIN /3
# ## 14:00 = 2 HOME WINS, 1 AWAY WIN, 2 AWAY LOSS,2 HOME DRAWS,1 HOME LOSS /8
# ## 12:30 = 2 HOME WINS,2 AWAY WINS / 4

# %% [markdown]
# <hr>

# %% [markdown]
# # which team scored the most goals?

# %%
pd.DataFrame(copy_df['HomeTeam'].value_counts())
# Out:
#                 HomeTeam
# Nottingham            19
# Leeds                 19
# Chelsea               19
# Aston Villa           19
# West Ham              19
# Brighton              19
# Liverpool             19
# Everton               19
# Bournemouth           19
# Southampton           19
# Wolves                19
# Man United            19
# Tottenham             19
# Leicester             19
# Fulham                19
# Crystal Palace        19
# Newcastle             19
# Brentford             19
# Arsenal               19
# Man City              19

# %%
copy_df
# Out:
#            Date   Time        HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    05/08/2022  20:00  Crystal Palace      Arsenal     0     2   A     0
# 1    06/08/2022  12:30          Fulham    Liverpool     2     2   D     1
# 2    06/08/2022  15:00     Bournemouth  Aston Villa     2     0   H     1
# 3    06/08/2022  15:00           Leeds       Wolves     2     1   H     1
# 4    06/08/2022  15:00       Newcastle   Nottingham     2     0   H     0
# ..          ...    ...             ...          ...   ...   ...  ..   ...
# 375  28/05/2023  16:30         Everton  Bournemouth     1     0   H     0
# 376  28/05/2023  16:30           Leeds    Tottenham     1     4   A     0
# 377  28/05/2023  16:30       Leicester     West Ham     2     1   H     1
# 378  28/05/2023  16:30      Man United       Fulham     2     1   H     1
# 379  28/05/2023  16:30     Southampton    Liverpool     4     4   D     2
#
#      HTAG HTR  ... HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# ...

# %%
# Get a list of unique club names from both 'HomeTeam' and 'AwayTeam' columns
home_club_names = copy_df['HomeTeam'].unique()
away_club_names = copy_df['AwayTeam'].unique()
club_names = sorted(set(home_club_names) | set(away_club_names))

# Create a dictionary to store the data for each club
club_data = {}

# Iterate over each club and extract their data
for club_name in club_names:
    home_data = copy_df[copy_df['HomeTeam'] == club_name]
    away_data = copy_df[copy_df['AwayTeam'] == club_name]
    club_data[club_name] = pd.concat([home_data, away_data])

# Save the data for each club in separate CSV files
for club_name, data in club_data.items():
    file_name = f'{club_name}_data.csv'
    data.to_csv(file_name, index=False)

# %%
len(home_club_names)
# Out:
# 20

# %%
len(away_club_names)
# Out:
# 20

# %%
club_names
# Out:
# ['Arsenal',
#  'Aston Villa',
#  'Bournemouth',
#  'Brentford',
#  'Brighton',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Fulham',
#  'Leeds',
#  'Leicester',
#  'Liverpool',
#  'Man City',
#  'Man United',
#  'Newcastle',
#  'Nottingham',
#  'Southampton',
#  'Tottenham',
#  'West Ham',
#  'Wolves']

# %%
crystal_palace = pd.read_csv("Crystal Palace_data.csv")
Arsenal = pd.read_csv("Arsenal_data.csv")
Aston_Villa = pd.read_csv("Aston Villa_data.csv")
Bournemouth = pd.read_csv("Bournemouth_data.csv")
Brentford = pd.read_csv("Brentford_data.csv")
Brighton = pd.read_csv("Brighton_data.csv")
Chelsea = pd.read_csv("Chelsea_data.csv")
Everton = pd.read_csv("Everton_data.csv")
Fulham = pd.read_csv("Fulham_data.csv")
Leeds= pd.read_csv("Leeds_data.csv")
Leicester= pd.read_csv("Leicester_data.csv")
Liverpool= pd.read_csv("Liverpool_data.csv")
Man_City= pd.read_csv("Man City_data.csv")
Man_United= pd.read_csv("Man United_data.csv")
Newcastle= pd.read_csv("Newcastle_data.csv")
Nottingham= pd.read_csv("Nottingham_data.csv")
Southampton= pd.read_csv("Southampton_data.csv")
Tottenham= pd.read_csv("Tottenham_data.csv")
West_Ham= pd.read_csv("West Ham_data.csv")
Wolves= pd.read_csv("Wolves_data.csv")

# %% [markdown]
# Lets calculate goals scored by each club

# %%
crystal_palace_goals = crystal_palace['FTHG'][:20].sum() + crystal_palace['FTAG'][20:].sum() 
crystal_palace_goals
# Out:
# 40

# %%
Arsenal_goals = Arsenal['FTHG'][:19].sum() + Arsenal['FTAG'][19:].sum()
Arsenal_goals
# Out:
# 88

# %%
Aston_villa_goals = Aston_Villa['FTHG'][:19].sum() + Aston_Villa['FTAG'][19:].sum()
Aston_villa_goals
# Out:
# 51

# %%
Manc_goals = Man_City['FTHG'][:19].sum() + Man_City['FTAG'][19:].sum()

# %%
Manc_goals
# Out:
# 94

# %%
Brentford_goals =Brentford['FTHG'][:19].sum() + Brentford['FTAG'][19:].sum()
Brighton_goals=Brighton['FTHG'][:19].sum() + Brighton['FTAG'][19:].sum()
Chelsea_goals =Chelsea['FTHG'][:19].sum() + Chelsea['FTAG'][19:].sum()
Everton_goals = Everton['FTHG'][:19].sum() + Everton['FTAG'][19:].sum()
Fulham_goals =Fulham['FTHG'][:19].sum() + Fulham['FTAG'][19:].sum()
Leeds_goals = Leeds['FTHG'][:19].sum() + Leeds['FTAG'][19:].sum()
Leicester_goals =Leicester['FTHG'][:19].sum() + Leicester['FTAG'][19:].sum()
Liverpool_goals =Liverpool['FTHG'][:19].sum() + Liverpool['FTAG'][19:].sum()
Man_United_goals =Man_United['FTHG'][:19].sum() + Man_United['FTAG'][19:].sum()
Newcastle_goals =Newcastle['FTHG'][:19].sum() + Newcastle['FTAG'][19:].sum()
Nottingham_goals =Nottingham['FTHG'][:19].sum() + Nottingham['FTAG'][19:].sum()
Southampton_goals =Southampton['FTHG'][:19].sum() + Southampton['FTAG'][19:].sum()
Tottenham_goals =Tottenham['FTHG'][:19].sum() + Tottenham['FTAG'][19:].sum()
West_Ham_goals =West_Ham['FTHG'][:19].sum() + West_Ham['FTAG'][19:].sum()
Wolves_goals =Wolves['FTHG'][:19].sum() + Wolves['FTAG'][19:].sum()
Bournemouth_goals =Bournemouth['FTHG'][:19].sum() + Bournemouth['FTAG'][19:].sum()

# %%
values_clubs = [crystal_palace_goals,Arsenal_goals,Aston_villa_goals,Manc_goals,Brentford_goals,Brighton_goals,Chelsea_goals,Everton_goals,Fulham_goals,Leeds_goals,Leicester_goals
         ,Liverpool_goals,Man_United_goals,Newcastle_goals,Nottingham_goals,Southampton_goals,Tottenham_goals,West_Ham_goals,Wolves_goals,Bournemouth_goals]
data_clubs = ['crystal_palace','Arsenal','Aston_villa','ManCity','Brentford','Brighton','Chelsea','Everton','Fulham','Leeds UTD','Leicester'
         ,'Liverpool','Manchester UTD','Newcastle UTD','Nottingham Forest','Southampton','Tottenham','West Ham','Wolves','Bournemouth']

# %%
plt.figure(figsize = (15,7))

plt.title("GOALS SCORED BY EACH CLUB",fontdict={'size':16,'weight':'bold'})

sns.barplot(x = data_clubs,y=values_clubs,width=0.5 )
for i, value in enumerate(values_clubs):
    plt.text(i, value, str(value), ha='center', va='bottom')

plt.xticks(rotation = 90)

plt.xlabel("CLUB NAMES",fontdict={'size':16,'weight':'bold'})

plt.ylabel("TOTAL GOALS SCORED",fontdict={'size':16,'weight':'bold'})

ax = plt.gca()

ax.tick_params(axis='x', labelsize=14, width=2, labelcolor='black')

plt.grid(True)
# # Add the values on top of each bar
# for i, v in enumerate(values_clubs):
#     ax.text(i, v + 1, str(v), ha='center', va='bottom')

# %% [markdown]
# ### So as per the chart, Manchester City has scored the most goals: 94 goals in 2022-23 season of Premier League

# %% [markdown]
# <hr>

# %% [markdown]
# # which team had the best defensive record?

# %%
crystal_palace_goals = crystal_palace['FTAG'][:20].sum() + crystal_palace['FTHG'][20:].sum() 
Arsenal_goals = Arsenal['FTAG'][:19].sum() + Arsenal['FTHG'][19:].sum()
Aston_villa_goals = Aston_Villa['FTAG'][:19].sum() + Aston_Villa['FTHG'][19:].sum()
Manc_goals = Man_City['FTAG'][:19].sum() + Man_City['FTHG'][19:].sum()
Brentford_goals =Brentford['FTAG'][:19].sum() + Brentford['FTHG'][19:].sum()
Brighton_goals=Brighton['FTAG'][:19].sum() + Brighton['FTHG'][19:].sum()
Chelsea_goals =Chelsea['FTAG'][:19].sum() + Chelsea['FTHG'][19:].sum()
Everton_goals = Everton['FTAG'][:19].sum() + Everton['FTHG'][19:].sum()
Fulham_goals =Fulham['FTAG'][:19].sum() + Fulham['FTHG'][19:].sum()
Leeds_goals = Leeds['FTAG'][:19].sum() + Leeds['FTHG'][19:].sum()
Leicester_goals =Leicester['FTAG'][:19].sum() + Leicester['FTHG'][19:].sum()
Liverpool_goals =Liverpool['FTAG'][:19].sum() + Liverpool['FTHG'][19:].sum()
Man_United_goals =Man_United['FTAG'][:19].sum() + Man_United['FTHG'][19:].sum()
Newcastle_goals =Newcastle['FTAG'][:19].sum() + Newcastle['FTHG'][19:].sum()
Nottingham_goals =Nottingham['FTAG'][:19].sum() + Nottingham['FTHG'][19:].sum()
Southampton_goals =Southampton['FTAG'][:19].sum() + Southampton['FTHG'][19:].sum()
Tottenham_goals =Tottenham['FTAG'][:19].sum() + Tottenham['FTHG'][19:].sum()
West_Ham_goals =West_Ham['FTAG'][:19].sum() + West_Ham['FTHG'][19:].sum()
Wolves_goals =Wolves['FTAG'][:19].sum() + Wolves['FTHG'][19:].sum()
Bournemouth_goals =Bournemouth['FTAG'][:19].sum() + Bournemouth['FTHG'][19:].sum()

# %%
values_clubs_conceded = [crystal_palace_goals,Arsenal_goals,Aston_villa_goals,Manc_goals,Brentford_goals,Brighton_goals,Chelsea_goals,Everton_goals,Fulham_goals,Leeds_goals,Leicester_goals
         ,Liverpool_goals,Man_United_goals,Newcastle_goals,Nottingham_goals,Southampton_goals,Tottenham_goals,West_Ham_goals,Wolves_goals,Bournemouth_goals]
data_clubs_conceded = ['crystal_palace','Arsenal','Aston_villa','ManCity','Brentford','Brighton','Chelsea','Everton','Fulham','Leeds UTD','Leicester'
         ,'Liverpool','Manchester UTD','Newcastle UTD','Nottingham Forest','Southampton','Tottenham','West Ham','Wolves','Bournemouth']

# %%
plt.figure(figsize = (15,7))

plt.title("GOALS CONCEDED BY EACH CLUB",fontdict={'size':16,'weight':'bold'})

sns.barplot(x = data_clubs_conceded,y=values_clubs_conceded,width=0.5 )
for i, value in enumerate(values_clubs_conceded):
    plt.text(i, value, str(value), ha='center', va='bottom')
plt.xticks(rotation = 90)

plt.xlabel("CLUB NAMES",fontdict={'size':16,'weight':'bold'})

plt.ylabel("TOTAL GOALS CONCEDED",fontdict={'size':16,'weight':'bold'})

ax = plt.gca()

ax.tick_params(axis='x', labelsize=14, width=2, labelcolor='black')

plt.grid(True)

# %% [markdown]
# As we can see, The teams which had the best defensive record in 2022-23 season are Manchester City and Newcastle United with a total of only 33 goals conceded

# %%
logo_df = pd.read_csv("epl_clubs_info_2022-23.csv")

# %%
logo_df
# Out:
#          club_name  abv hex_code  \
# 0          Arsenal  ARS  #EF0107
# 1      Aston Villa  AVL  #95BFE5
# 2      Bournemouth  BOU  #C91318
# 3        Brentford  BRE  #E30613
# 4         Brighton  BRI  #005DAA
# 5          Chelsea  CHE  #034694
# 6   Crystal Palace  CRY  #1B458F
# 7          Everton  EVE  #003399
# 8           Fulham  FUL  #000000
# 9            Leeds  LEE  #FFCD00
# 10       Leicester  LEI  #FDBE11
# 11       Liverpool  LIV  #00A398
# 12        Man City  MNC  #6CABDD
# 13      Man United  MNU  #DA291C
# 14       Newcastle  NEW  #41B6E6
# 15      Nottingham  NFC  #DD0000
# 16     Southampton  SOU  #ed1a3b
# 17       Tottenham  TOT  #0A1C56
# 18        West Ham  WHM  #7A263A
# 19          Wolves  WOL  #FDB913
#
#                                             logo_link
# 0   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 1   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# 2   https://a.espncdn.com/i/teamlogos/soccer/500/3...
# ...

# %%
# Out:
# club_name    object
# abv          object
# hex_code     object
# logo_link    object
# dtype: object

# %%
import matplotlib.image as mpimg

# %%
links = []
for i in logo_df['logo_link']:
    links.append(i)

# %%
# Load team logos
logos = [mpimg.imread(path) for path in links]

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# Sample data
# categories = ['Team A', 'Team B', 'Team C']
# values = [25, 50, 75]

# Load team logos
logos = [mpimg.imread(path) for path in links]

# Create the bar plot
fig, ax = plt.subplots(figsize = (20,10))
bars = ax.bar(data_clubs_conceded, values_clubs_conceded)

# Add team logos to the bars
for bar, logo in zip(bars, logos):
    imagebox = ax.imshow(logo, extent=[bar.get_x(), bar.get_x() + bar.get_width(), 0, bar.get_height()], aspect='auto', zorder=2)

# Add value labels to each bar
for i, value in enumerate(values):
    plt.text(i, value, str(value), ha='center', va='bottom')

# Remove the default x-axis ticks and labels
ax.tick_params(bottom=False)

# Display the plot
plt.show()

# %%
# Add team logos to the bars
for bar, logo in zip(bars, logos):
    imagebox = ax.imshow(logo, extent=[bar.get_x(), bar.get_x() + bar.get_width(), 0, bar.get_height()], aspect='auto', zorder=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-e78356133beb> in <module>
#       1 # Add team logos to the bars
# ----> 2 for bar, logo in zip(bars, logos):
#       3     imagebox = ax.imshow(logo, extent=[bar.get_x(), bar.get_x() + bar.get_width(), 0, bar.get_height()], aspect='auto', zorder=2)
#
# TypeError: 'AxesSubplot' object is not iterable

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from IPython.display import display, Image

# Sample data
categories = ['Team A', 'Team B', 'Team C']
values = [25, 50, 75]
logo_paths = ['logos/crystaL_palace.png',
 'logos/arsenal.png',
 'logos/aston_villa.png',
 'logos/manc.png',
 'logos/brentford.png',
 'logos/brighton.png',
 'logos/chelseae.png',
 'logos/Everton.png',
 'logos/fulham.png',
 'logos/leeds.png',
 'logos/leceister.png',
 'logos/liverpool.png',
 'logos/manu.png',
 'logos/newcastle.png',
 'logos/nottingham.png',
 'logos/southampton.png',
 'logos/tottenham.png',
 'logos/westham.png',
 'logos/wolves.png',
 'logos/bournemouth.png']

# Create the bar plot
fig, ax = plt.subplots(figsize=(20,10))
bars = ax.bar(data_clubs_conceded, values_clubs_conceded)

# Add team logos to the bars
for bar, logo_path in zip(bars, logo_paths):
    image = Image(filename=logo_path, width=30, height=30)
    display(image)

# Add value labels to each bar
for i, value in enumerate(values_clubs_conceded):
    plt.text(i, value, str(value), ha='center', va='bottom')

# Remove the default x-axis ticks and labels
ax.tick_params(bottom=False)

# Display the plot
plt.show()

# %%
data_clubs_conceded
# Out:
# ['crystal_palace',
#  'Arsenal',
#  'Aston_villa',
#  'ManCity',
#  'Brentford',
#  'Brighton',
#  'Chelsea',
#  'Everton',
#  'Fulham',
#  'Leeds UTD',
#  'Leicester',
#  'Liverpool',
#  'Manchester UTD',
#  'Newcastle UTD',
#  'Nottingham Forest',
#  'Southampton',
#  'Tottenham',
#  'West Ham',
#  'Wolves',
#  'Bournemouth']
