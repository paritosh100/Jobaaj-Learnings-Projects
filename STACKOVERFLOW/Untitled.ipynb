# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# %%
df = pd.read_csv("survey_results_public.csv")

# %%
df.shape
# Out:
# (73268, 79)

# %%
df.isnull().sum()
# Out:
# ResponseId                 0
# MainBranch                 0
# Employment              1559
# RemoteWork             14310
# CodingActivities       14369
#                        ...
# TrueFalse_2            37553
# TrueFalse_3            37519
# SurveyLength            2824
# SurveyEase              2760
# ConvertedCompYearly    35197
# Length: 79, dtype: int64

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
df.tail()
# Out:
#        ResponseId                                         MainBranch  \
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 73263                                Employed, full-time
# 73264                                Employed, full-time
# 73265                                Employed, full-time
# 73266                                Employed, full-time
# 73267  Independent contractor, freelancer, or self-em...
#
#                                  RemoteWork  \
# 73263                          Fully remote
# 73264                        Full in-person
# 73265  Hybrid (some remote, some in-person)
# ...

# %%
print(df['EdLevel'].unique(),end = ' ')
# Out:
# [nan 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)'
#  'Bachelor’s degree (B.A., B.S., B.Eng., etc.)'
#  'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)'
#  'Some college/university study without earning a degree' 'Something else'
#  'Primary/elementary school' 'Other doctoral degree (Ph.D., Ed.D., etc.)'
#  'Associate degree (A.A., A.S., etc.)'
#  'Professional degree (JD, MD, etc.)']

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df.dtypes
# Out:
# ResponseId               int64
# MainBranch              object
# Employment              object
# RemoteWork              object
# CodingActivities        object
#                         ...
# TrueFalse_2             object
# TrueFalse_3             object
# SurveyLength            object
# SurveyEase              object
# ConvertedCompYearly    float64
# Length: 79, dtype: object

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
copy_df = df.copy()

# %%
copy_df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %% [markdown]
# #  1.at what companies do the developers get paid the most?

# %%
copy_df['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   53507
# I am learning to code                                                             6309
# I am not primarily a developer, but I write code sometimes as part of my work     5794
# I code primarily as a hobby                                                       4865
# None of these                                                                     1497
# I used to be a developer by profession, but no longer am                          1296
# Name: MainBranch, dtype: int64

# %%
copy_df['ConvertedCompYearly'].isna().sum()
# Out:
# 35197

# %%
(copy_df['ConvertedCompYearly'].value_counts())
# Out:
# 150000.0    393
# 200000.0    362
# 120000.0    341
# 63986.0     304
# 100000.0    279
#            ...
# 124060.0      1
# 22824.0       1
# 78473.0       1
# 62034.0       1
# 23280.0       1
# Name: ConvertedCompYearly, Length: 7909, dtype: int64

# %%
plt.figure(figsize=(20,10))
copy_df['ConvertedCompYearly'].plot()
plt.show()

# %%
copy_df.describe()
# Out:
#          ResponseId     CompTotal  VCHostingPersonal use  \
# count  73268.000000  3.842200e+04                    0.0
# mean   36634.500000  2.342434e+52                    NaN
# std    21150.794099  4.591478e+54                    NaN
# min        1.000000  0.000000e+00                    NaN
# 25%    18317.750000  3.000000e+04                    NaN
# 50%    36634.500000  7.750000e+04                    NaN
# 75%    54951.250000  1.540000e+05                    NaN
# max    73268.000000  9.000000e+56                    NaN
#
#        VCHostingProfessional use       WorkExp  ConvertedCompYearly
# count                        0.0  36769.000000         3.807100e+04
# mean                         NaN     10.242378         1.707613e+05
# std                          NaN      8.706850         7.814132e+05
# min                          NaN      0.000000         1.000000e+00
# 25%                          NaN      4.000000         3.583200e+04
# ...

# %%
copy_df['ConvertedCompYearly'].mean(skipna=True)
# Out:
# 170761.2778492816

# %%
copy_df['ConvertedCompYearly'].max()
# Out:
# 50000000.0

# %%
copy_df['ConvertedCompYearly'].min()
# Out:
# 1.0

# %%
copy_df['ConvertedCompYearly'].fillna(value=copy_df['ConvertedCompYearly'].mean(),inplace=True)

# %%
copy_df.describe()
# Out:
#          ResponseId     CompTotal  VCHostingPersonal use  \
# count  73268.000000  3.842200e+04                    0.0
# mean   36634.500000  2.342434e+52                    NaN
# std    21150.794099  4.591478e+54                    NaN
# min        1.000000  0.000000e+00                    NaN
# 25%    18317.750000  3.000000e+04                    NaN
# 50%    36634.500000  7.750000e+04                    NaN
# 75%    54951.250000  1.540000e+05                    NaN
# max    73268.000000  9.000000e+56                    NaN
#
#        VCHostingProfessional use       WorkExp  ConvertedCompYearly
# count                        0.0  36769.000000         7.326800e+04
# mean                         NaN     10.242378         1.707613e+05
# std                          NaN      8.706850         5.632718e+05
# min                          NaN      0.000000         1.000000e+00
# 25%                          NaN      4.000000         6.453325e+04
# ...

# %%
copy_df['ConvertedCompYearly'].mean(skipna=True)
# Out:
# 170761.27784924436

# %%
copy_df['ConvertedCompYearly'].isna().sum()
# Out:
# 0

# %%
plt.figure(figsize=(20,10))
copy_df['ConvertedCompYearly'].plot()
plt.show()

# %%
top_companies = copy_df[['MainBranch','ConvertedCompYearly']]
top_companies
# Out:
#                                               MainBranch  ConvertedCompYearly
# 0                                          None of these        170761.277849
# 1                         I am a developer by profession        170761.277849
# 2      I am not primarily a developer, but I write co...         40205.000000
# 3                         I am a developer by profession        215232.000000
# 4                         I am a developer by profession        170761.277849
# ...                                                  ...                  ...
# 73263                     I am a developer by profession        170761.277849
# 73264                     I am a developer by profession        170761.277849
# 73265  I am not primarily a developer, but I write co...        170761.277849
# 73266                     I am a developer by profession        170761.277849
# 73267  I used to be a developer by profession, but no...        170761.277849
#
# [73268 rows x 2 columns]

# %%
sorted_top_companies = copy_df.sort_values("ConvertedCompYearly",ascending=False)[0:9]

# %%
sorted_top_companies
# Out:
#        ResponseId                      MainBranch  \
# 40304       40305  I am a developer by profession
# 201           202  I am a developer by profession
# 62026       62027  I am a developer by profession
# 70522       70523  I am a developer by profession
# 61043       61044  I am a developer by profession
# 62223       62224  I am a developer by profession
# 18922       18923  I am a developer by profession
# 66495       66496  I am a developer by profession
# 1290         1291  I am a developer by profession
#
#                                               Employment  \
# 40304  Independent contractor, freelancer, or self-em...
# 201                                  Employed, full-time
# 62026                                Employed, full-time
# 70522  Independent contractor, freelancer, or self-em...
# 61043                                I prefer not to say
# 62223                                Employed, full-time
# 18922                                Employed, full-time
# ...

# %%
vs =sorted_top_companies['EdLevel'].value_counts()
vs
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          6
# Primary/elementary school                                                             1
# Other doctoral degree (Ph.D., Ed.D., etc.)                                            1
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)    1
# Name: EdLevel, dtype: int64

# %% [markdown]
# # from the below chart we can infer that employees with Education level as "Bachelor’s degree (B.A., B.S., B.Eng., etc.) " get paid the most.

# %%
plt.figure(figsize = (20,5))
sns.histplot(data = sorted_top_companies,x = "EdLevel")
plt.xticks(rotation = 90)
plt.show()

# %%
pd.DataFrame(copy_df['DevType'].value_counts())
# Out:
#                                                     DevType
# Developer, full-stack                                  7142
# Developer, back-end                                    5301
# Developer, front-end                                   2385
# Developer, front-end;Developer, full-stack;Deve...     1807
# Developer, full-stack;Developer, back-end              1535
# ...                                                     ...
# Developer, back-end;Developer, QA or test;Educa...        1
# Developer, front-end;Engineer, site reliability...        1
# Developer, full-stack;Developer, desktop or ent...        1
# Engineer, data;Developer, full-stack;Educator;D...        1
# Developer, full-stack;Developer, back-end;Devel...        1
#
# [9984 rows x 1 columns]

# %%
copy_df['DevType'].isna().sum()
# Out:
# 11966

# %%
copy_df['DevType'].fillna(value = "Developer",inplace=True)

# %%
copy_df['DevType'].isnull().sum()
# Out:
# 0

# %%
df_dev = copy_df[copy_df['DevType'].str.contains("Developer")]

# %%
df_dev
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73262       73263                              I am learning to code
# 73263       73264                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
df_dev.shape
# Out:
# (63892, 79)

# %%
df.shape
# Out:
# (73268, 79)

# %%
df['EdLevel'].unique()
# Out:
# array([nan, 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#        'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        'Some college/university study without earning a degree',
#        'Something else', 'Primary/elementary school',
#        'Other doctoral degree (Ph.D., Ed.D., etc.)',
#        'Associate degree (A.A., A.S., etc.)',
#        'Professional degree (JD, MD, etc.)'], dtype=object)

# %%
pd.DataFrame(df['DevType'].value_counts())
# Out:
#                                                     DevType
# Developer, full-stack                                  7142
# Developer, back-end                                    5301
# Developer, front-end                                   2385
# Developer, front-end;Developer, full-stack;Deve...     1807
# Developer, full-stack;Developer, back-end              1535
# ...                                                     ...
# Developer, back-end;Developer, QA or test;Educa...        1
# Developer, front-end;Engineer, site reliability...        1
# Developer, full-stack;Developer, desktop or ent...        1
# Engineer, data;Developer, full-stack;Educator;D...        1
# Developer, full-stack;Developer, back-end;Devel...        1
#
# [9984 rows x 1 columns]

# %%
master_dev = df_dev[df_dev['EdLevel'] == "Master’s degree (M.A., M.S., M.Eng., MBA, etc.)"]

# %%
master_dev.shape
# Out:
# (12764, 79)

# %%
masters = copy_df[copy_df['EdLevel'] == "Master’s degree (M.A., M.S., M.Eng., MBA, etc.)"]

# %%
masters.shape
# Out:
# (15486, 79)

# %%
masters

# %%
copy_df['DevType'] = copy_df['DevType'].replace(copy_df['DevType'].str.contains("Developer"),"Developer",inplace=True)

# %%
pd.DataFrame(copy_df['DevType'].value_counts())
# Out:
#                                                     DevType
# Developer                                             11966
# Developer, full-stack                                  7142
# Developer, back-end                                    5301
# Developer, front-end                                   2385
# Developer, front-end;Developer, full-stack;Deve...     1807
# ...                                                     ...
# Developer, back-end;Developer, QA or test;Educa...        1
# Developer, front-end;Engineer, site reliability...        1
# Developer, full-stack;Developer, desktop or ent...        1
# Engineer, data;Developer, full-stack;Educator;D...        1
# Developer, full-stack;Developer, back-end;Devel...        1
#
# [9985 rows x 1 columns]

# %%
pd.DataFrame(copy_df['DevType'].value_counts())
# Out:
# Empty DataFrame
# Columns: [DevType]
# Index: []

# %%
copy_df['DevType'] = df['DevType']

# %%
copy_df['DevType']
# Out:
# 0                                                      NaN
# 1                                                      NaN
# 2        Data scientist or machine learning specialist;...
# 3                                    Developer, full-stack
# 4        Developer, front-end;Developer, full-stack;Dev...
#                                ...
# 73263                                  Developer, back-end
# 73264        Data scientist or machine learning specialist
# 73265    Developer, full-stack;Developer, desktop or en...
# 73266    Developer, front-end;Developer, desktop or ent...
# 73267    Developer, front-end;Engineer, data;Engineer, ...
# Name: DevType, Length: 73268, dtype: object

# %%
#Pie chart to analyze how much % of Employees holding a Master's Degree are Developers
plt.figure(figsize=(10,10))
data = [2722,12764]
keys = ['Other DevTypes', 'Developers']
explode = [0, 0.1]
palette_color = sns.color_palette('bright')
plt.pie(data, labels=keys, colors=['tomato', 'cornflowerblue'], autopct='%.0f%%',explode = explode,textprops={'fontsize': 16})
# plt.xlabel("Other DevType",fontdict={'Size ' : 30})
plt.show()

# %% [markdown]
# ## from the above chart, it can be said that about ~82% of employees holding a masters degree have a devtype as developer

# %%
sorted_top_companies['YearsCode'].value_counts()
# Out:
# Less than 1 year    2
# 9                   1
# 6                   1
# 22                  1
# 15                  1
# 8                   1
# 10                  1
# 36                  1
# Name: YearsCode, dtype: int64

# %%
sorted_top_companies[['YearsCode','ConvertedCompYearly']]
# Out:
#               YearsCode  ConvertedCompYearly
# 40304  Less than 1 year           50000000.0
# 201                   9           44790396.0
# 62026                 6           35000000.0
# 70522                22           32500000.0
# 61043  Less than 1 year           28853768.0
# 62223                15           22500000.0
# 18922                36           22500000.0
# 66495                 8           18000000.0
# 1290                 10           15000000.0

# %% [markdown]
# from the below chart we can say, years of coding experience does not matter as the highest paid employee has less than 1 year of experience with contrary to this an employee
# with 36 years of coding experience get lesser pay than the employee with less than 1 year of coding experience.
#
# While the mean salary is ~39426884.0 for an employee with less than 1 year of coding experience. one employee with same experience get 50000000.0 while the other with same
# experience gets 28853768.0 salary yearly.
#
# So, coding experience is essential but with that critical thinking plays vital role in achieving this type of salaries.

# %%
plt.figure(figsize = (20,5))
sns.barplot(data = sorted_top_companies,x = "YearsCode",y='ConvertedCompYearly')
plt.xticks(rotation = 90)
plt.show()
