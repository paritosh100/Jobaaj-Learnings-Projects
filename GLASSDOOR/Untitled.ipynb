# %%
import pandas as pd
import numpy as np
import re

# %%
df_og_cleaned = pd.read_csv("Salary Dataset.csv")

# %%
df_og_cleaned.head(10)
# Out:
#                      Company Name       Job Title  Salaries Reported  \
# 0                        Mu Sigma  Data Scientist              105.0
# 1                             IBM  Data Scientist               95.0
# 2       Tata Consultancy Services  Data Scientist               66.0
# 3                Impact Analytics  Data Scientist               40.0
# 4                       Accenture  Data Scientist               32.0
# 5                         Infosys  Data Scientist               30.0
# 6                       Capgemini  Data Scientist               28.0
# 7  Cognizant Technology Solutions  Data Scientist               26.0
# 8            Anheuser-Busch InBev  Data Scientist               25.0
# 9                         Fractal  Data Scientist               22.0
#
#     Location         Salary
# 0  Bangalore   ₹6,48,573/yr
# 1  Bangalore  ₹11,91,950/yr
# 2  Bangalore   ₹8,36,874/yr
# 3  Bangalore   ₹6,69,578/yr
# 4  Bangalore   ₹9,44,110/yr
# 5  Bangalore   ₹9,08,764/yr
# ...

# %%
df_og_cleaned.describe()
# Out:
#        Salaries Reported
# count        4342.000000
# mean            2.775910
# std             5.146527
# min             1.000000
# 25%             1.000000
# 50%             1.000000
# 75%             3.000000
# max           105.000000

# %%
df_og_cleaned.columns
# Out:
# Index(['Company Name', 'Job Title', 'Salaries Reported', 'Location', 'Salary'], dtype='object')

# %%
df_og_cleaned[['Company Name', 'Job Title',  'Location', 'Salary']].describe()
# Out:
#                      Company Name       Job Title   Location         Salary
# count                        4341            4344       4344           4344
# unique                       2529              26          5           3101
# top     Tata Consultancy Services  Data Scientist  Bangalore  ₹10,00,000/yr
# freq                           41            1844       1584             24

# %%
df_og_cleaned["Company Name"].unique()
# Out:
# array(['Mu Sigma', 'IBM', 'Tata Consultancy Services', ...,
#        'Myraa Technologies', 'TaiyōAI', 'Market Pulse Technologies'],
#       dtype=object)

# %%
df_ds_cp = df_og_cleaned.copy()

# %%
df_ds_cp
# Out:
#                    Company Name                             Job Title  \
# 0                      Mu Sigma                        Data Scientist
# 1                           IBM                        Data Scientist
# 2     Tata Consultancy Services                        Data Scientist
# 3              Impact Analytics                        Data Scientist
# 4                     Accenture                        Data Scientist
# ...                         ...                                   ...
# 4339                    TaiyōAI            Machine Learning Scientist
# 4340    Decimal Point Analytics            Machine Learning Developer
# 4341                     MyWays            Machine Learning Developer
# 4342  Market Pulse Technologies  Software Engineer - Machine Learning
# 4343                    vPhrase             Machine Learning Engineer
#
#       Salaries Reported   Location         Salary
# 0                 105.0  Bangalore   ₹6,48,573/yr
# ...

# %%
df_ds_cp[['Company Name', 'Job Title', 'Salaries Reported', 'Location', 'Salary']].tail(10)
# Out:
#                    Company Name                             Job Title  \
# 4334            iPing Data Labs             Machine Learning Engineer
# 4335             Tekolutions.AI             Machine Learning Engineer
# 4336                    Zipgigz             Machine Learning Engineer
# 4337                        SCI             Machine Learning Engineer
# 4338         Myraa Technologies            Machine Learning Scientist
# 4339                    TaiyōAI            Machine Learning Scientist
# 4340    Decimal Point Analytics            Machine Learning Developer
# 4341                     MyWays            Machine Learning Developer
# 4342  Market Pulse Technologies  Software Engineer - Machine Learning
# 4343                    vPhrase             Machine Learning Engineer
#
#       Salaries Reported Location         Salary
# 4334                1.0   Mumbai     ₹10,491/mo
# 4335                1.0   Mumbai      ₹8,039/mo
# 4336                1.0   Mumbai      ₹8,145/mo
# ...

# %%
df_ds_cp.dtypes
# Out:
# Company Name          object
# Job Title             object
# Salaries Reported    float64
# Location              object
# Salary                object
# dtype: object

# %%
df_mumbai = df_ds_cp[df_ds_cp['Location']=='Mumbai']

# %%
df_mumbai.describe()
# Out:
#        Salaries Reported
# count         617.000000
# mean            2.562399
# std             4.963151
# min             1.000000
# 25%             1.000000
# 50%             1.000000
# 75%             2.000000
# max            81.000000

# %%
df_ds_cp["Salary"] = df_og_cleaned['Salary']

# %%
df_ds_cp["Salary"] = df_ds_cp["Salary"].str.replace("₹","")
df_ds_cp
# Out:
#                    Company Name                             Job Title  \
# 0                      Mu Sigma                        Data Scientist
# 1                           IBM                        Data Scientist
# 2     Tata Consultancy Services                        Data Scientist
# 3              Impact Analytics                        Data Scientist
# 4                     Accenture                        Data Scientist
# ...                         ...                                   ...
# 4339                    TaiyōAI            Machine Learning Scientist
# 4340    Decimal Point Analytics            Machine Learning Developer
# 4341                     MyWays            Machine Learning Developer
# 4342  Market Pulse Technologies  Software Engineer - Machine Learning
# 4343                    vPhrase             Machine Learning Engineer
#
#       Salaries Reported   Location      Salary
# 0                 105.0  Bangalore    6,48,573
# ...

# %%
df_ds_cp["Salary"] = df_ds_cp["Salary"].str.replace("/",'')
df_ds_cp["Salary"] = df_ds_cp["Salary"].str.replace("yr",'')
df_ds_cp["Salary"] = df_ds_cp["Salary"].str.replace("mo",'')
df_ds_cp
# Out:
#                    Company Name                             Job Title  \
# 0                      Mu Sigma                        Data Scientist
# 1                           IBM                        Data Scientist
# 2     Tata Consultancy Services                        Data Scientist
# 3              Impact Analytics                        Data Scientist
# 4                     Accenture                        Data Scientist
# ...                         ...                                   ...
# 4339                    TaiyōAI            Machine Learning Scientist
# 4340    Decimal Point Analytics            Machine Learning Developer
# 4341                     MyWays            Machine Learning Developer
# 4342  Market Pulse Technologies  Software Engineer - Machine Learning
# 4343                    vPhrase             Machine Learning Engineer
#
#       Salaries Reported   Location      Salary
# 0                 105.0  Bangalore    6,48,573
# ...

# %%
df_ds_cp["Salary"].str.contain(r'[0-9]+')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-fdc05c0d99cb> in <module>
# ----> 1 df_ds_cp["Salary"].str.contain(r'[0-9]+')
#
# AttributeError: 'StringMethods' object has no attribute 'contain'
